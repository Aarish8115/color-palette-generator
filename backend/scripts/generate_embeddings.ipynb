# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
data=pd.read_parquet("../data/cleaned-colors.parquet",engine="pyarrow")

# %%
data.columns
# Out:
# Index(['color_name', 'hex', 'category', 'keywords', 'hue_family',
#        'search_text', 'rgb', 'hsl', 'brightness', 'warmth', 'contrast_score',
#        'color_style', 'color_id'],
#       dtype='str')

# %%
model=SentenceTransformer("../models/embedding")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 11473.24it/s]

# %%
embeddings=model.encode(data["search_text"].to_list(),show_progress_bar=True)
# Out:
# Batches: 100%|██████████| 3125/3125 [48:40<00:00,  1.07it/s]

# %%
np.save("../data/embeddings.npy",embeddings)
